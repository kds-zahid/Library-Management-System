# %% [markdown]
# <a href="https://colab.research.google.com/github/kds-zahid/Library-Management-System/blob/main/Z_data_scrapper_backlink.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install requests
# !pip install beautifulsoup4

import requests
from bs4 import BeautifulSoup

def get_backlinks(url):
    try:
        # Make a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all <a> tags in the HTML
            a_tags = soup.find_all('a')

            # Extract and print the href attribute from each <a> tag
            for a_tag in a_tags:
                href = a_tag.get('href')
                if href:
                    print(href)
        else:
            print(f"Error: Unable to fetch the page. Status code: {response.status_code}")

    except Exception as e:
        print(f"An error occurred: {e}")

# Replace 'your_website_url' with the actual URL you want to analyze
website_url = 'https://www.latestdatabase.com/country-email-list/'
get_backlinks(website_url)
# Out:
# ...
# https://www.latestdatabase.com
# https://wa.me/8801918754549
# https://wa.me/8801918754549
# https://wa.me/8801918754549
# https://t.me/latestdbs
# https://www.latestdatabase.com/shop/
# https://www.latestdatabase.com
# http://www.latestdatabase.com/build-email-list/
# https://www.latestdatabase.com/
# https://www.latestdatabase.com/phone-number-list/
# https://www.latestdatabase.com/whatsapp-mobile-number-list/
# https://www.latestdatabase.com/special-database/
# https://www.latestdatabase.com/buy-bulk-sms-service/
# https://www.latestdatabase.com/country-email-list/
# https://www.latestdatabase.com/b2b-email-list/
# https://www.latestdatabase.com/c-level-executive-list/
# https://www.latestdatabase.com/job-function-email-database/
# https://www.latestdatabase.com/industry-email-list/
# https://www.latestdatabase.com/fax-lists/
# https://www.latestdatabase.com/
# https://www.latestdatabase.com/phone-number-list/
# https://www.latestdatabase.com/whatsapp-mobile-number-list/
# ...
